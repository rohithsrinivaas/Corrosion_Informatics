# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_rows", None)

# %%
df_base = pd.read_excel('../Data/EIS_bode/base.xlsx') 
df_ht = pd.read_excel('../Data/EIS_bode/ht.xlsx') 
df_sp = pd.read_excel('../Data/EIS_bode/sp.xlsx') 
df_htsp = pd.read_excel('../Data/EIS_bode/htsp.xlsx')

# %%
df_base = df_base.iloc[2:]

# %%
df_ht = df_ht.iloc[1:]

# %%
df_sp = df_sp.iloc[2:]

# %%
df_htsp = df_htsp.iloc[1:]

# %% [markdown]
# ## Adding the postprocessing feature columns in the datatset

# %%
df_base = df_base.rename(columns={"Unnamed: 0": "XY"})
df_sp = df_sp.rename(columns={"Unnamed: 0": "XY"})

# %%
df_base["T"] = 0*np.ones((df_base.shape[0],1))
df_base["t"] = 0*np.ones((df_base.shape[0],1))
df_base["incl"] = 0*np.ones((df_base.shape[0],1))
df_base["vel"] = 0*np.ones((df_base.shape[0],1))

# %%
df_ht["T"] = 980*np.ones((df_ht.shape[0],1))
df_ht["t"] = 15*np.ones((df_ht.shape[0],1))
df_ht["incl"] = 0*np.ones((df_ht.shape[0],1))
df_ht["vel"] = 0*np.ones((df_ht.shape[0],1))

# %%
df_sp["T"] = 0*np.ones((df_sp.shape[0],1))
df_sp["t"] = 0*np.ones((df_sp.shape[0],1))
df_sp["incl"] = 60*np.ones((df_sp.shape[0],1))
df_sp["vel"] = 70*np.ones((df_sp.shape[0],1))

# %%
df_htsp["T"] = 980*np.ones((df_htsp.shape[0],1))
df_htsp["t"] = 15*np.ones((df_htsp.shape[0],1))
df_htsp["incl"] = 60*np.ones((df_htsp.shape[0],1))
df_htsp["vel"] = 70*np.ones((df_htsp.shape[0],1))

# %%
plt.plot(np.log(df_base["Unnamed: 2"].values),df_base["Unnamed: 3"].values,'r',label = 'base')
plt.plot(np.log(df_ht["Unnamed: 2"].values),df_ht["Unnamed: 3"].values,'b',label = 'HT')
plt.plot(np.log(df_sp["Unnamed: 2"].values),df_sp["Unnamed: 3"].values,'g',label = 'SP')
plt.plot(np.log(df_htsp["Unnamed: 2"].values),df_htsp["Unnamed: 3"].values,'y',label = 'HTSP')
plt.legend()
plt.title('Bode plot')
plt.xlabel('log(freq)')
plt.ylabel('phase angle')
plt.show()

# %%
df_base.columns
# Out:
# Index(['XY', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'T', 't', 'incl',
#        'vel'],
#       dtype='object')

# %%
df_base = df_base.rename(columns={"Unnamed: 1":"absZ","Unnamed: 3": "phase","Unnamed: 2":"f"})
df_ht = df_ht.rename(columns={"Unnamed: 1":"absZ","Unnamed: 3": "phase","Unnamed: 2":"f"})
df_sp = df_sp.rename(columns={"Unnamed: 1":"absZ","Unnamed: 3": "phase","Unnamed: 2":"f"})
df_htsp = df_htsp.rename(columns={"Unnamed: 1":"absZ","Unnamed: 3": "phase","Unnamed: 2":"f"})

# %%
df_base["f"] = np.log(df_base["f"].values)
df_ht["f"] = np.log(df_ht["f"].values)
df_sp["f"] = np.log(df_sp["f"].values)
df_htsp["f"] = np.log(df_htsp["f"].values)

# %%
df_base["absZ"] = np.log(df_base["absZ"].astype('float64').values)
df_ht["absZ"] = np.log(df_ht["absZ"].astype('float64').values)
df_sp["absZ"] = np.log(df_sp["absZ"].astype('float64').values)
df_htsp["absZ"] = np.log(df_htsp["absZ"].astype('float64').values)

# %%
df_base = df_base.rename(columns={"f":"log(f)","absZ":"log(absZ)"})
df_ht = df_ht.rename(columns={"f":"log(f)","absZ":"log(absZ)"})
df_sp = df_sp.rename(columns={"f":"log(f)","absZ":"log(absZ)"})
df_htsp = df_htsp.rename(columns={"f":"log(f)","absZ":"log(absZ)"})

# %%
result_df = pd.concat([df_base,df_ht,df_sp,df_htsp])

# %%
result_df["phase"] = result_df["phase"].values.astype('float64')

# %%
result_df = result_df.drop(['XY'], axis=1)

# %%
phase_df = result_df.drop(['log(absZ)'], axis=1)

# %%
absZ_df = result_df.drop(['log(f)'], axis=1)

# %%
phase_df.shape
# Out:
# (284, 6)

# %%
print_df = phase_df.rename(columns={'phase':'phase_angle'})

# %%
print_df.head()
# Out:
#       log(f)  phase_angle    T    t  incl  vel
# 2  11.513925       -1.548  0.0  0.0   0.0  0.0
# 3  11.282883       -1.663  0.0  0.0   0.0  0.0
# 4  11.053110       -1.715  0.0  0.0   0.0  0.0
# 5  10.823770       -1.856  0.0  0.0   0.0  0.0
# 6  10.593881       -2.169  0.0  0.0   0.0  0.0

# %%
print_df.to_csv('Bode_data.csv',index=False)

# %%
x, y = phase_df.drop(['phase'], axis=1), phase_df['phase'].values.astype('float64')

# %% [markdown]
# ## Fitting a XGboost Model

# %%
import xgboost as xgb

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score, r2_score, mean_squared_error, mean_absolute_error
from math import sqrt
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=42)
xgb_model = xgb.XGBRegressor(random_state = 0)
xgb_model.fit(x_train,y_train)
#R2
#MAE
#RMSE
print(r2_score(y_test,xgb_model.predict(x_test)))
print(mean_absolute_error(y_test,xgb_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,xgb_model.predict(x_test))))
# Out:
# [17:13:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.9902215458927924
# 2.1685692248790818
# 2.9175425710388825

# %%
xgb_model.get_params()
# Out:
# {'base_score': 0.5,
#  'booster': 'gbtree',
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 1,
#  'gamma': 0,
#  'importance_type': 'gain',
#  'learning_rate': 0.1,
#  'max_delta_step': 0,
#  'max_depth': 3,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 100,
#  'n_jobs': 1,
#  'nthread': None,
#  'objective': 'reg:linear',
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'seed': None,
#  'silent': None,
#  'subsample': 1,
#  'verbosity': 1}

# %%
plt.plot(df_base["log(f)"].values,df_base["phase"].values,'r',label = 'Experimental')
plt.plot(df_base["log(f)"].values,xgb_model.predict(df_base.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('Base')
plt.savefig('bode_xgb_ab.png',dpi=1200)
plt.show()

# %%
plt.plot(df_ht["log(f)"].values,df_ht["phase"].values,'r',label = 'Experimental')
plt.plot(df_ht["log(f)"].values,xgb_model.predict(df_ht.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('HT')
plt.savefig('bode_xgb_ht.png',dpi=1200)
plt.show()

# %%
plt.plot(df_sp["log(f)"].values,df_sp["phase"].values,'r',label = 'Experimental')
plt.plot(df_sp["log(f)"].values,xgb_model.predict(df_sp.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('SP')
plt.savefig('bode_xgb_sp.png',dpi=1200)
plt.show()

# %%
plt.plot(df_htsp["log(f)"].values,df_htsp["phase"].values,'r',label = 'Experimental')
plt.plot(df_htsp["log(f)"].values,xgb_model.predict(df_htsp.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('htsp')
plt.savefig('bode_xgb_htsp.png',dpi=1200)
plt.show()

# %% [markdown]
# ## Fitting a Support Vector Regression

# %%
from sklearn import svm
svr_model = svm.SVR(kernel='rbf', C=4, gamma=0.1, epsilon=.1,degree=3)
svr_model.fit(x_train,y_train)
#R2
#MAE
#RMSE
print(r2_score(y_test,svr_model.predict(x_test)))
print(mean_absolute_error(y_test,svr_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,svr_model.predict(x_test))))
# Out:
# 0.9892196683683648
# 1.9227375329808643
# 3.0633608755528314

# %%
svr_model.get_params()
# Out:
# {'C': 4,
#  'cache_size': 200,
#  'coef0': 0.0,
#  'degree': 3,
#  'epsilon': 0.1,
#  'gamma': 0.1,
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
plt.plot(df_base["log(f)"].values,df_base["phase"].values,'r',label = 'Experimental')
plt.plot(df_base["log(f)"].values,svr_model.predict(df_base.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('Base')
plt.savefig('bode_svm_ab.png',dpi=1200)
plt.show()

# %%
plt.plot(df_ht["log(f)"].values,df_ht["phase"].values,'r',label = 'Experimental')
plt.plot(df_ht["log(f)"].values,svr_model.predict(df_ht.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('ht')
plt.savefig('bode_svm_ht.png',dpi=1200)
plt.show()

# %%
plt.plot(df_sp["log(f)"].values,df_sp["phase"].values,'r',label = 'Experimental')
plt.plot(df_sp["log(f)"].values,svr_model.predict(df_sp.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('sp')
plt.savefig('bode_svm_sp.png',dpi=1200)
plt.show()

# %%
plt.plot(df_htsp["log(f)"].values,df_htsp["phase"].values,'r',label = 'Experimental')
plt.plot(df_htsp["log(f)"].values,svr_model.predict(df_htsp.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('htsp')
plt.savefig('bode_svm_htsp.png',dpi=1200)
plt.show()

# %% [markdown]
# ## Fitting a Decision Tree

# %%
from sklearn import tree
dt_model = tree.DecisionTreeRegressor(max_depth=6)
dt_model.fit(x_train,y_train)
#R2
#MAE
#RMSE
print(r2_score(y_test,dt_model.predict(x_test)))
print(mean_absolute_error(y_test,dt_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,dt_model.predict(x_test))))
# Out:
# 0.9856390517784311
# 2.7451105231647777
# 3.535685756565331

# %%
dt_model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'mse',
#  'max_depth': 6,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': 'deprecated',
#  'random_state': None,
#  'splitter': 'best'}

# %%
plt.plot(df_base["log(f)"].values,df_base["phase"].values,'r',label = 'Experimental')
plt.plot(df_base["log(f)"].values,dt_model.predict(df_base.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('Base')
plt.savefig('bode_dt_ab.png',dpi=1200)
plt.show()

# %%
plt.plot(df_ht["log(f)"].values,df_ht["phase"].values,'r',label = 'Experimental')
plt.plot(df_ht["log(f)"].values,dt_model.predict(df_ht.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('ht')
plt.savefig('bode_dt_ht.png',dpi=1200)
plt.show()

# %%
plt.plot(df_sp["log(f)"].values,df_sp["phase"].values,'r',label = 'Experimental')
plt.plot(df_sp["log(f)"].values,dt_model.predict(df_sp.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('sp')
plt.savefig('bode_dt_sp.png',dpi=1200)
plt.show()

# %%
plt.plot(df_htsp["log(f)"].values,df_htsp["phase"].values,'r',label = 'Experimental')
plt.plot(df_htsp["log(f)"].values,dt_model.predict(df_htsp.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('htsp')
plt.savefig('bode_dt_htsp.png',dpi=1200)
plt.show()

# %% [markdown]
# ## Fitting a Polynomial Regreesion

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

linear_model = LinearRegression()
degree=5
poly_model =make_pipeline(PolynomialFeatures(degree),LinearRegression())

poly_model.fit(x_train,y_train)
#R2
#MAE
#RMSE
print(r2_score(y_test,poly_model.predict(x_test)))
print(mean_absolute_error(y_test,poly_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,poly_model.predict(x_test))))
# Out:
# 0.9849172114995248
# 3.0678412490455567
# 3.623455410835078

# %%
plt.plot(df_base["log(f)"].values,df_base["phase"].values,'r',label = 'Experimental')
plt.plot(df_base["log(f)"].values,poly_model.predict(df_base.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('Base')
plt.savefig('bode_poly_ab.png',dpi=1200)
plt.show()

# %%
plt.plot(df_ht["log(f)"].values,df_ht["phase"].values,'r',label = 'Experimental')
plt.plot(df_ht["log(f)"].values,poly_model.predict(df_ht.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('ht')
plt.savefig('bode_poly_ht.png',dpi=1200)
plt.show()

# %%
plt.plot(df_sp["log(f)"].values,df_sp["phase"].values,'r',label = 'Experimental')
plt.plot(df_sp["log(f)"].values,poly_model.predict(df_sp.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('sp')
plt.savefig('bode_poly_sp.png',dpi=1200)
plt.show()

# %%
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,AutoMinorLocator)
fig, ax = plt.subplots()

# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.


ax.plot(df_htsp["log(f)"].values,df_htsp["phase"].values,'r',label = 'Experimental')
ax.plot(df_htsp["log(f)"].values,poly_model.predict(df_htsp.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')

ax.yaxis.set_major_locator(MultipleLocator(10))
ax.yaxis.set_major_formatter(FormatStrFormatter('%d'))

plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('htsp')
plt.savefig('bode_poly_htsp.png',dpi=1200)
plt.show()

# %% [markdown]
# ## XGBoost Feature Importance

# %%
from xgboost import plot_importance
#reduction in mse
plot_importance(xgb_model)
plt.show()

# %% [markdown]
# Among the models considered, XGBoost performs the best. So we will do hyperparameter optimisation for XgBoost using Optuna
# # Optuna For Hyperparameter Optimisation

# %%
import optuna

# %% [markdown]
# ## Xgboost

# %%
def xgb_objective(trial):
    train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.15)
    param = {
        'silent': 1,
        'random_state': 0,
        'objective': 'reg:linear',
        'booster': trial.suggest_categorical('booster', ['gbtree', 'gblinear', 'dart']),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-4, 1.0),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-4, 1.0),
        'n_estimators': trial.suggest_int('n_estimators',10,100),
        'learning_rate': trial.suggest_loguniform('learning_rste', 1e-4, 0.1),
        'max_depth':trial.suggest_int('max_depth',3,6)
    }
    bst = xgb.XGBRegressor(**param)
    bst.fit(train_x,train_y)
    return sqrt(mean_squared_error(test_y,bst.predict(test_x)))

# %%
SEED = 42

np.random.seed(SEED)
xgb_study = optuna.create_study(direction='minimize',sampler=optuna.samplers.TPESampler(seed=SEED),pruner=optuna.pruners.SuccessiveHalvingPruner())
xgb_study.optimize(xgb_objective, n_trials=100)
# Out:
# [I 2021-04-02 10:38:20,405] A new study created in memory with name: no-name-3c68ae71-bc91-4be2-8985-87f5f79175c3
# [I 2021-04-02 10:38:20,510] Trial 0 finished with value: 32.616829341633355 and parameters: {'booster': 'dart', 'reg_lambda': 0.15352246941973485, 'reg_alpha': 0.000541675458324746, 'n_estimators': 81, 'learning_rste': 0.006251373574521752, 'max_depth': 5}. Best is trial 0 with value: 32.616829341633355.
# [I 2021-04-02 10:38:20,530] Trial 1 finished with value: 43.677507769063354 and parameters: {'booster': 'gblinear', 'reg_lambda': 0.0004207053950287938, 'reg_alpha': 0.0001707396743152812, 'n_estimators': 97, 'learning_rste': 0.0010025956902289571, 'max_depth': 6}. Best is trial 0 with value: 32.616829341633355.
# [I 2021-04-02 10:38:20,564] Trial 2 finished with value: 56.24581772733734 and parameters: {'booster': 'dart', 'reg_lambda': 0.00012087541473056971, 'reg_alpha': 0.7579479953348001, 'n_estimators': 39, 'learning_rste': 0.0004335281794951569, 'max_depth': 6}. Best is trial 0 with value: 32.616829341633355.
# [I 2021-04-02 10:38:20,618] Trial 3 finished with value: 51.35612762095036 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.02950706670790533, 'reg_alpha': 0.02796485951606245, 'n_estimators': 98, 'learning_rste': 0.0007476312062252305, 'max_depth': 5}. Best is trial 0 with value: 32.616829341633355.
# [I 2021-04-02 10:38:20,687] Trial 4 finished with value: 52.16609339581564 and parameters: {'booster': 'dart', 'reg_lambda': 0.0003613894271216529, 'reg_alpha': 0.0014742753159914669, 'n_estimators': 89, 'learning_rste': 0.0004992453416923984, 'max_depth': 4}. Best is trial 0 with value: 32.616829341633355.
# [I 2021-04-02 10:38:20,731] Trial 5 finished with value: 47.01014120134056 and parameters: {'booster': 'dart', 'reg_lambda': 0.029753909473493843, 'reg_alpha': 0.003387255565852149, 'n_estimators': 73, 'learning_rste': 0.0025135566617708314, 'max_depth': 3}. Best is trial 0 with value: 32.616829341633355.
# [I 2021-04-02 10:38:20,756] Trial 6 finished with value: 8.747691229180939 and parameters: {'booster': 'dart', 'reg_lambda': 0.05262961031076742, 'reg_alpha': 0.006338653441536257, 'n_estimators': 27, 'learning_rste': 0.07025166339242159, 'max_depth': 6}. Best is trial 6 with value: 8.747691229180939.
# [I 2021-04-02 10:38:20,779] Trial 7 finished with value: 52.86085596258917 and parameters: {'booster': 'gblinear', 'reg_lambda': 0.17123375973163968, 'reg_alpha': 0.001653693718282443, 'n_estimators': 62, 'learning_rste': 0.0004928122297695504, 'max_depth': 6}. Best is trial 6 with value: 8.747691229180939.
# [I 2021-04-02 10:38:20,793] Trial 8 finished with value: 58.48266948252828 and parameters: {'booster': 'dart', 'reg_lambda': 0.054082165807184904, 'reg_alpha': 0.0275414392133203, 'n_estimators': 17, 'learning_rste': 0.00012681352169084607, 'max_depth': 4}. Best is trial 6 with value: 8.747691229180939.
# [I 2021-04-02 10:38:20,826] Trial 9 finished with value: 54.1575112540286 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0010842262717330165, 'reg_alpha': 0.04467752817973906, 'n_estimators': 11, 'learning_rste': 0.0018856783874794994, 'max_depth': 4}. Best is trial 6 with value: 8.747691229180939.
# [I 2021-04-02 10:38:20,863] Trial 10 finished with value: 25.541029292017246 and parameters: {'booster': 'gblinear', 'reg_lambda': 0.8773051777432617, 'reg_alpha': 0.36254937642833174, 'n_estimators': 34, 'learning_rste': 0.08946769895739001, 'max_depth': 5}. Best is trial 6 with value: 8.747691229180939.
# [I 2021-04-02 10:38:20,893] Trial 11 finished with value: 23.072763940881256 and parameters: {'booster': 'gblinear', 'reg_lambda': 0.9658848165074733, 'reg_alpha': 0.5301624317871871, 'n_estimators': 34, 'learning_rste': 0.09209287774740992, 'max_depth': 5}. Best is trial 6 with value: 8.747691229180939.
# [I 2021-04-02 10:38:20,920] Trial 12 finished with value: 27.518548994940915 and parameters: {'booster': 'gblinear', 'reg_lambda': 0.7086720584387374, 'reg_alpha': 0.1512359995557746, 'n_estimators': 33, 'learning_rste': 0.07529157984813298, 'max_depth': 6}. Best is trial 6 with value: 8.747691229180939.
# [I 2021-04-02 10:38:20,959] Trial 13 finished with value: 31.30624130230294 and parameters: {'booster': 'gblinear', 'reg_lambda': 0.004446942933838136, 'reg_alpha': 0.008471174978164417, 'n_estimators': 47, 'learning_rste': 0.018483744845159713, 'max_depth': 5}. Best is trial 6 with value: 8.747691229180939.
# [I 2021-04-02 10:38:20,992] Trial 14 finished with value: 33.381563354832785 and parameters: {'booster': 'gblinear', 'reg_lambda': 0.30676965894461516, 'reg_alpha': 0.11469849954973828, 'n_estimators': 22, 'learning_rste': 0.03157288172603374, 'max_depth': 6}. Best is trial 6 with value: 8.747691229180939.
# [I 2021-04-02 10:38:21,040] Trial 15 finished with value: 23.74216044639799 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.005483159069997342, 'reg_alpha': 0.01131282654162483, 'n_estimators': 24, 'learning_rste': 0.03564849857978423, 'max_depth': 5}. Best is trial 6 with value: 8.747691229180939.
# [I 2021-04-02 10:38:21,097] Trial 16 finished with value: 41.28398814884605 and parameters: {'booster': 'dart', 'reg_lambda': 0.9182571408154488, 'reg_alpha': 0.006308719007728853, 'n_estimators': 47, 'learning_rste': 0.00815518655137768, 'max_depth': 3}. Best is trial 6 with value: 8.747691229180939.
# [I 2021-04-02 10:38:21,176] Trial 17 finished with value: 2.173782844002689 and parameters: {'booster': 'dart', 'reg_lambda': 0.06817179886221593, 'reg_alpha': 0.00010446251525877409, 'n_estimators': 57, 'learning_rste': 0.07315451983828174, 'max_depth': 5}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:21,250] Trial 18 finished with value: 23.76388712677188 and parameters: {'booster': 'dart', 'reg_lambda': 0.06047926594615573, 'reg_alpha': 0.00018335053461176207, 'n_estimators': 62, 'learning_rste': 0.014074840077919015, 'max_depth': 6}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:21,313] Trial 19 finished with value: 5.25618996551373 and parameters: {'booster': 'dart', 'reg_lambda': 0.014467053264901546, 'reg_alpha': 0.0004531292986525192, 'n_estimators': 57, 'learning_rste': 0.04440695804797892, 'max_depth': 4}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:21,376] Trial 20 finished with value: 4.4439766651581225 and parameters: {'booster': 'dart', 'reg_lambda': 0.010980559689899532, 'reg_alpha': 0.00010627962696740669, 'n_estimators': 69, 'learning_rste': 0.04286054501063888, 'max_depth': 4}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:21,478] Trial 21 finished with value: 5.667103991744595 and parameters: {'booster': 'dart', 'reg_lambda': 0.008850167060989985, 'reg_alpha': 0.0001006635469546757, 'n_estimators': 68, 'learning_rste': 0.039764294212206994, 'max_depth': 4}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:21,603] Trial 22 finished with value: 19.131026277878796 and parameters: {'booster': 'dart', 'reg_lambda': 0.002531408590524887, 'reg_alpha': 0.0004418525058465911, 'n_estimators': 57, 'learning_rste': 0.019015367321548536, 'max_depth': 4}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:21,714] Trial 23 finished with value: 3.3786575097230775 and parameters: {'booster': 'dart', 'reg_lambda': 0.013997672682687779, 'reg_alpha': 0.00010022391796891409, 'n_estimators': 76, 'learning_rste': 0.04838732493370051, 'max_depth': 3}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:21,787] Trial 24 finished with value: 34.40369272422915 and parameters: {'booster': 'dart', 'reg_lambda': 0.016359325626307625, 'reg_alpha': 0.00010740189958903167, 'n_estimators': 75, 'learning_rste': 0.006402837892621652, 'max_depth': 3}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:21,858] Trial 25 finished with value: 3.293765503507469 and parameters: {'booster': 'dart', 'reg_lambda': 0.0020372546279615066, 'reg_alpha': 0.000271254734020293, 'n_estimators': 84, 'learning_rste': 0.0551808713443168, 'max_depth': 3}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:21,937] Trial 26 finished with value: 2.8111028563181777 and parameters: {'booster': 'dart', 'reg_lambda': 0.0025155792009299324, 'reg_alpha': 0.0002541632997572739, 'n_estimators': 85, 'learning_rste': 0.09766256378679365, 'max_depth': 3}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:22,008] Trial 27 finished with value: 8.668007963750547 and parameters: {'booster': 'dart', 'reg_lambda': 0.0013827674274883893, 'reg_alpha': 0.00026089803129803027, 'n_estimators': 87, 'learning_rste': 0.021711851902304503, 'max_depth': 3}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:22,073] Trial 28 finished with value: 2.588186759115644 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0006788400570822874, 'reg_alpha': 0.0009565159103764635, 'n_estimators': 91, 'learning_rste': 0.09814791315708098, 'max_depth': 3}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:22,190] Trial 29 finished with value: 20.842366275892655 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.000533130042069126, 'reg_alpha': 0.0013985304540591419, 'n_estimators': 92, 'learning_rste': 0.010389314642801841, 'max_depth': 5}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:22,265] Trial 30 finished with value: 38.30945604621457 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.00012322972651886626, 'reg_alpha': 0.000931716549002793, 'n_estimators': 99, 'learning_rste': 0.004640371407685895, 'max_depth': 3}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:22,355] Trial 31 finished with value: 3.0226332456903524 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0018242430383630488, 'reg_alpha': 0.0007032039242226731, 'n_estimators': 83, 'learning_rste': 0.06618802148680761, 'max_depth': 3}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:22,413] Trial 32 finished with value: 2.4381633219080263 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0002519337060188435, 'reg_alpha': 0.0008025941371162806, 'n_estimators': 92, 'learning_rste': 0.09184157539642965, 'max_depth': 3}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:22,470] Trial 33 finished with value: 2.2423187470389734 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.00020464730111344388, 'reg_alpha': 0.0029715995803760286, 'n_estimators': 92, 'learning_rste': 0.09517627215142477, 'max_depth': 3}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:22,538] Trial 34 finished with value: 2.720700760153061 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0002240862260169022, 'reg_alpha': 0.00280248966486968, 'n_estimators': 93, 'learning_rste': 0.09639074013090251, 'max_depth': 3}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:22,594] Trial 35 finished with value: 5.855274943516595 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0007234393395524525, 'reg_alpha': 0.002413322020644522, 'n_estimators': 100, 'learning_rste': 0.02524150844523605, 'max_depth': 3}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:22,660] Trial 36 finished with value: 53.331549446226646 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.00021606198249534347, 'reg_alpha': 0.0009102299382041388, 'n_estimators': 95, 'learning_rste': 0.00018462523868273314, 'max_depth': 4}. Best is trial 17 with value: 2.173782844002689.
# [I 2021-04-02 10:38:22,769] Trial 37 finished with value: 1.8385198698080711 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0002071648167227751, 'reg_alpha': 0.004107378340119757, 'n_estimators': 80, 'learning_rste': 0.0979061814427685, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:22,864] Trial 38 finished with value: 2.715014835770316 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0001043897132184417, 'reg_alpha': 0.005360075655635597, 'n_estimators': 79, 'learning_rste': 0.06570103170303442, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:22,898] Trial 39 finished with value: 13.772711047185124 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0002887961160656413, 'reg_alpha': 0.015408134300629551, 'n_estimators': 49, 'learning_rste': 0.028430107216033305, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:22,934] Trial 40 finished with value: 52.60630833127422 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.00015884932352193014, 'reg_alpha': 0.003407935821895589, 'n_estimators': 80, 'learning_rste': 0.0012141605997636306, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:22,975] Trial 41 finished with value: 2.7284621435776844 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0004940615628070947, 'reg_alpha': 0.0013983025021710623, 'n_estimators': 89, 'learning_rste': 0.06030164116695517, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,020] Trial 42 finished with value: 2.1386318659310715 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0007901212220112784, 'reg_alpha': 0.0045037347873869635, 'n_estimators': 95, 'learning_rste': 0.09624438688531868, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,064] Trial 43 finished with value: 2.3741919822141098 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.00036152609086237007, 'reg_alpha': 0.004464079124496359, 'n_estimators': 100, 'learning_rste': 0.09929496772774776, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,121] Trial 44 finished with value: 2.0431619676121775 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0003793944219890966, 'reg_alpha': 0.017985545625651172, 'n_estimators': 100, 'learning_rste': 0.06520362168564954, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,206] Trial 45 finished with value: 2.738543134094485 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0009535547328618737, 'reg_alpha': 0.024553072363815015, 'n_estimators': 97, 'learning_rste': 0.0555925398959308, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,283] Trial 46 finished with value: 2.031954800039971 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.1037591226424992, 'reg_alpha': 0.01788642297910229, 'n_estimators': 69, 'learning_rste': 0.07373481800431099, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,370] Trial 47 finished with value: 23.379146290231546 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.11110076643623142, 'reg_alpha': 0.057208287253251465, 'n_estimators': 69, 'learning_rste': 0.013162417966495898, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,433] Trial 48 finished with value: 6.8707421246488245 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.4246172506043773, 'reg_alpha': 0.01603915051087083, 'n_estimators': 65, 'learning_rste': 0.03369281695823056, 'max_depth': 6}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,518] Trial 49 finished with value: 2.0405476204861555 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.11658829648878026, 'reg_alpha': 0.04808030955568208, 'n_estimators': 72, 'learning_rste': 0.07271082628073075, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,597] Trial 50 finished with value: 2.4754628816574287 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.16100913016182988, 'reg_alpha': 0.04578363416198669, 'n_estimators': 71, 'learning_rste': 0.06949549856772376, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,643] Trial 51 finished with value: 2.5210459202533873 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.08544029557319834, 'reg_alpha': 0.09131394168164074, 'n_estimators': 54, 'learning_rste': 0.07349040000259087, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,681] Trial 52 finished with value: 3.514713375821474 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.03078958324141145, 'reg_alpha': 0.24668832561673326, 'n_estimators': 65, 'learning_rste': 0.046770616997609364, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,725] Trial 53 finished with value: 2.389988419045688 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.2529606868400855, 'reg_alpha': 0.008921424551582244, 'n_estimators': 63, 'learning_rste': 0.07450589312478831, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,766] Trial 54 finished with value: 3.467481887210651 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.03647771244925958, 'reg_alpha': 0.025234206282733145, 'n_estimators': 77, 'learning_rste': 0.03922738338843561, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,811] Trial 55 finished with value: 7.06226960571546 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.10175839865243959, 'reg_alpha': 0.015381523839475423, 'n_estimators': 73, 'learning_rste': 0.02901799521466227, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,843] Trial 56 finished with value: 25.12664872359772 and parameters: {'booster': 'gblinear', 'reg_lambda': 0.5049046618598869, 'reg_alpha': 0.07256886393254824, 'n_estimators': 60, 'learning_rste': 0.0550182966112292, 'max_depth': 6}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,916] Trial 57 finished with value: 2.532358382464058 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.058738494269469796, 'reg_alpha': 0.03819519740087124, 'n_estimators': 50, 'learning_rste': 0.08528077796131368, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:23,958] Trial 58 finished with value: 22.66740611345383 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.21744142097080393, 'reg_alpha': 0.009970540367556513, 'n_estimators': 41, 'learning_rste': 0.023404160204950526, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:24,014] Trial 59 finished with value: 24.961679487789606 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.1410160686057539, 'reg_alpha': 0.03438310697798618, 'n_estimators': 55, 'learning_rste': 0.015357736365445403, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:24,047] Trial 60 finished with value: 22.81661558357305 and parameters: {'booster': 'gblinear', 'reg_lambda': 0.005299848806319505, 'reg_alpha': 0.9757495436088417, 'n_estimators': 81, 'learning_rste': 0.04759700169856685, 'max_depth': 6}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:24,120] Trial 61 finished with value: 2.029188314791188 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.00017811552144698234, 'reg_alpha': 0.01847597900217169, 'n_estimators': 87, 'learning_rste': 0.08436713664732562, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:24,164] Trial 62 finished with value: 2.4646062749650626 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.075724290176303, 'reg_alpha': 0.01959225300159773, 'n_estimators': 88, 'learning_rste': 0.07798878270715287, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:24,203] Trial 63 finished with value: 3.3086698322277472 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.00016386664504946583, 'reg_alpha': 0.006673458682598751, 'n_estimators': 84, 'learning_rste': 0.03654068012502977, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:24,239] Trial 64 finished with value: 2.551307208474946 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.04562875205749567, 'reg_alpha': 0.012157010149156228, 'n_estimators': 73, 'learning_rste': 0.054586709057392775, 'max_depth': 5}. Best is trial 37 with value: 1.8385198698080711.
# [I 2021-04-02 10:38:24,302] Trial 65 finished with value: 1.6383231676785117 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.021203087154445525, 'reg_alpha': 0.021003022258342486, 'n_estimators': 95, 'learning_rste': 0.09891241258294202, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:24,358] Trial 66 finished with value: 2.5149010920878916 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0003380390748076712, 'reg_alpha': 0.007484644922524038, 'n_estimators': 96, 'learning_rste': 0.08208103279174385, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:24,398] Trial 67 finished with value: 2.689250979660078 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.01760524783447357, 'reg_alpha': 0.0220553908426342, 'n_estimators': 86, 'learning_rste': 0.09771309085218893, 'max_depth': 4}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:24,458] Trial 68 finished with value: 55.732727995061595 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.00013693474429381426, 'reg_alpha': 0.004509739567691834, 'n_estimators': 78, 'learning_rste': 0.00032514004636425246, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:24,522] Trial 69 finished with value: 2.0044938529317795 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.020317917861573043, 'reg_alpha': 0.011879323391478213, 'n_estimators': 82, 'learning_rste': 0.06078328756490808, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:24,590] Trial 70 finished with value: 2.437445380815499 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.022904002430944138, 'reg_alpha': 0.031084012648289066, 'n_estimators': 82, 'learning_rste': 0.0610399364788564, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:24,696] Trial 71 finished with value: 3.12870081198775 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.008049433717077567, 'reg_alpha': 0.012288449863736072, 'n_estimators': 95, 'learning_rste': 0.04833593440321591, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:24,767] Trial 72 finished with value: 2.314660445882874 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.046997947734566725, 'reg_alpha': 0.0535549270584828, 'n_estimators': 89, 'learning_rste': 0.07815537697830847, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:24,818] Trial 73 finished with value: 3.2827197716923573 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.022758121346158976, 'reg_alpha': 0.002112405274330169, 'n_estimators': 76, 'learning_rste': 0.041960188875834574, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:24,879] Trial 74 finished with value: 2.3440891787645546 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0005765892689488537, 'reg_alpha': 0.018488653645166282, 'n_estimators': 94, 'learning_rste': 0.06140746221532158, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:24,949] Trial 75 finished with value: 1.8723986695392119 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.011549549044491722, 'reg_alpha': 0.012782234742172705, 'n_estimators': 90, 'learning_rste': 0.09945720130841623, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:25,019] Trial 76 finished with value: 5.0964383111670895 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.011426056161554635, 'reg_alpha': 0.010500064971516824, 'n_estimators': 90, 'learning_rste': 0.03252630755680329, 'max_depth': 6}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:25,070] Trial 77 finished with value: 47.312730544960495 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.007087110795822124, 'reg_alpha': 0.1574554658205526, 'n_estimators': 87, 'learning_rste': 0.002267648009885454, 'max_depth': 4}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:25,167] Trial 78 finished with value: 2.106905884782091 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.02039758244507764, 'reg_alpha': 0.02861264116614466, 'n_estimators': 81, 'learning_rste': 0.09968278761146122, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:25,293] Trial 79 finished with value: 1.8993697755152448 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.003512332201953036, 'reg_alpha': 0.013509179003009051, 'n_estimators': 73, 'learning_rste': 0.06559939894579303, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:25,397] Trial 80 finished with value: 3.0415674405871176 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0032517959041645696, 'reg_alpha': 0.013446116829735877, 'n_estimators': 74, 'learning_rste': 0.08446260040477006, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:25,464] Trial 81 finished with value: 2.006840612039316 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.01021277480752149, 'reg_alpha': 0.019172354669583266, 'n_estimators': 78, 'learning_rste': 0.06506830920576723, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:25,521] Trial 82 finished with value: 2.7314677821861544 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.004164425815702137, 'reg_alpha': 0.037913853828487915, 'n_estimators': 71, 'learning_rste': 0.05244785174948959, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:25,571] Trial 83 finished with value: 3.1104218830186205 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.011275934292574138, 'reg_alpha': 0.008410309546161667, 'n_estimators': 84, 'learning_rste': 0.04135869264341927, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:25,619] Trial 84 finished with value: 2.9545093708850847 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.006790010192232313, 'reg_alpha': 0.005873850528944696, 'n_estimators': 78, 'learning_rste': 0.06829945538698466, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:25,662] Trial 85 finished with value: 2.385606207512914 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.014689897761338748, 'reg_alpha': 0.02343710421992133, 'n_estimators': 66, 'learning_rste': 0.07725097059009223, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:25,711] Trial 86 finished with value: 44.66856381617511 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.029824488434655825, 'reg_alpha': 0.020155991748755285, 'n_estimators': 71, 'learning_rste': 0.003916913388981768, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:25,767] Trial 87 finished with value: 1.8918531297052466 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.008939116370911828, 'reg_alpha': 0.013794226508486586, 'n_estimators': 79, 'learning_rste': 0.08681027101302571, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:25,799] Trial 88 finished with value: 19.89811434038599 and parameters: {'booster': 'gblinear', 'reg_lambda': 0.009586265295817065, 'reg_alpha': 0.013931204579927648, 'n_estimators': 79, 'learning_rste': 0.09104479400883125, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:25,861] Trial 89 finished with value: 2.5152155344199985 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.005558589032762523, 'reg_alpha': 0.007586324898020366, 'n_estimators': 86, 'learning_rste': 0.055516012251407884, 'max_depth': 4}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:25,913] Trial 90 finished with value: 1.8802552444167835 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.012551343294411307, 'reg_alpha': 0.010745474096592555, 'n_estimators': 82, 'learning_rste': 0.06342710771981573, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:25,973] Trial 91 finished with value: 1.8816631616163546 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.012159541294792754, 'reg_alpha': 0.017110478404886813, 'n_estimators': 83, 'learning_rste': 0.09979766487958587, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:26,036] Trial 92 finished with value: 2.193578482347766 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.011555940488034207, 'reg_alpha': 0.010326683304811093, 'n_estimators': 82, 'learning_rste': 0.09693319361561879, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:26,096] Trial 93 finished with value: 2.2592273035977426 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.01323331890747986, 'reg_alpha': 0.005227279535115646, 'n_estimators': 76, 'learning_rste': 0.060875125473373606, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:26,162] Trial 94 finished with value: 2.7847817662483068 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.018022431715696813, 'reg_alpha': 0.01209562784983025, 'n_estimators': 91, 'learning_rste': 0.043543570849756096, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:26,213] Trial 95 finished with value: 2.175830219202766 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.03678079549431177, 'reg_alpha': 0.008956457829933958, 'n_estimators': 85, 'learning_rste': 0.09772432574430782, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:26,259] Trial 96 finished with value: 1.7289651115661835 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0082552878300045, 'reg_alpha': 0.0038682084444305732, 'n_estimators': 80, 'learning_rste': 0.08314484898763377, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:26,314] Trial 97 finished with value: 2.180107854884375 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0085047925768582, 'reg_alpha': 0.006922651604378309, 'n_estimators': 80, 'learning_rste': 0.04922809227464056, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:26,363] Trial 98 finished with value: 2.002745630601071 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.0035629558591978917, 'reg_alpha': 0.0034225035506446253, 'n_estimators': 82, 'learning_rste': 0.06410509315011644, 'max_depth': 5}. Best is trial 65 with value: 1.6383231676785117.
# [I 2021-04-02 10:38:26,425] Trial 99 finished with value: 1.4938656465293327 and parameters: {'booster': 'gbtree', 'reg_lambda': 0.004000806203116893, 'reg_alpha': 0.003689896166381573, 'n_estimators': 84, 'learning_rste': 0.08476142316168266, 'max_depth': 5}. Best is trial 99 with value: 1.4938656465293327.

# %%
from typing import Callable
from typing import Optional

import numpy as np

from optuna._experimental import experimental
from optuna.logging import get_logger
from optuna.study import Study
from optuna.study import StudyDirection
from optuna.trial import FrozenTrial
from optuna.trial import TrialState
from optuna.visualization._utils import _check_plot_args
from optuna.visualization.matplotlib._matplotlib_imports import _imports


if _imports.is_successful():
    from optuna.visualization.matplotlib._matplotlib_imports import Axes
    from optuna.visualization.matplotlib._matplotlib_imports import plt

_logger = get_logger(__name__)

# %%
def optimization_history(
    study: Study,
    *,
    target: Optional[Callable[[FrozenTrial], float]] = None,
    target_name: str = "Objective Value",
) -> "Axes":
    """Plot optimization history of all trials in a study with Matplotlib.
    .. seealso::
        Please refer to :func:`optuna.visualization.plot_optimization_history` for an example.
    Example:
        The following code snippet shows how to plot optimization history.
        .. plot::
            import optuna
            def objective(trial):
                x = trial.suggest_float("x", -100, 100)
                y = trial.suggest_categorical("y", [-1, 0, 1])
                return x ** 2 + y
            sampler = optuna.samplers.TPESampler(seed=10)
            study = optuna.create_study(sampler=sampler)
            study.optimize(objective, n_trials=10)
            optuna.visualization.matplotlib.plot_optimization_history(study)
    Args:
        study:
            A :class:`~optuna.study.Study` object whose trials are plotted for their target values.
        target:
            A function to specify the value to display. If it is :obj:`None` and ``study`` is being
            used for single-objective optimization, the objective values are plotted.
            .. note::
                Specify this argument if ``study`` is being used for multi-objective optimization.
        target_name:
            Target's name to display on the axis label and the legend.
    Returns:
        A :class:`matplotlib.axes.Axes` object.
    Raises:
        :exc:`ValueError`:
            If ``target`` is :obj:`None` and ``study`` is being used for multi-objective
            optimization.
    """

    _imports.check()
    _check_plot_args(study, target, target_name)
    get_optimization_history_plot(study, target, target_name)
    return 0


def get_optimization_history_plot(
    study: Study,
    target: Optional[Callable[[FrozenTrial], float]],
    target_name: str,
) -> "Axes":

    # Set up the graph style.
    fig = plt.figure()
    plt.title("Optimization History Plot")
    plt.xlabel("#Trials")
    plt.ylabel(target_name)
    
    # Prepare data for plotting.
    trials = [t for t in study.trials if t.state == TrialState.COMPLETE]

    if len(trials) == 0:
        _logger.warning("Study instance does not contain trials.")
        return 0

    # Draw a scatter plot and a line plot.
    if target is None:
        if study.direction == StudyDirection.MINIMIZE:
            best_values = np.minimum.accumulate([t.value for t in trials])
        else:
            best_values = np.maximum.accumulate([t.value for t in trials])
        plt.scatter(
            x=[t.number for t in trials],
            y=[t.value for t in trials],
            color='blue',
            alpha=1,
            label=target_name,
        )
        plt.plot(
            [t.number for t in trials],
            best_values,
            marker="o",
            color='red',
            alpha=0.5,
            label="Best Value",
        )

        plt.legend()
    else:
        plt.scatter(
            x=[t.number for t in trials],
            y=[target(t) for t in trials],
            color='red',
            alpha=1,
            label=target_name,
        )
    plt.savefig('bode_opt_his.png',dpi = 1200,bbox_inches='tight')
    plt.show()

# %%
optimization_history(xgb_study)
# Out:
# 0

# %%
xgb_study.best_params
# Out:
# {'booster': 'gbtree',
#  'reg_lambda': 0.004000806203116893,
#  'reg_alpha': 0.003689896166381573,
#  'n_estimators': 84,
#  'learning_rste': 0.08476142316168266,
#  'max_depth': 5}

# %%
bst_params = {'booster': 'gbtree',
 'reg_lambda': 0.004000806203116893,
 'reg_alpha': 0.003689896166381573,
 'n_estimators': 84,
 'learning_rste': 0.08476142316168266,
 'max_depth': 5}

# %%
final_model = xgb.XGBRegressor(**bst_params)
final_model.fit(x_train,y_train)
# Out:
# [15:24:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1,
#              learning_rste=0.08476142316168266, max_delta_step=0, max_depth=5,
#              min_child_weight=1, missing=None, n_estimators=84, n_jobs=1,
#              nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0.003689896166381573, reg_lambda=0.004000806203116893,
#              scale_pos_weight=1, seed=None, silent=None, subsample=1,
#              verbosity=1)

# %%
print(r2_score(y_test,final_model.predict(x_test)))
print(mean_absolute_error(y_test,final_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,final_model.predict(x_test))))
# Out:
# 0.9952219108405463
# 1.3654411260361363
# 2.0394319819350857

# %%
final_model.feature_importances_
# Out:
# array([0.98645735, 0.00622593, 0.        , 0.00731668, 0.        ],
#       dtype=float32)

# %%
columns = ['log(f)', 'T','incl']

# %%
gain = np.array([0.98645735, 0.00622593,0.00731668],
      dtype='float32')

# %%
def _label_barh(bars, text_format, **kwargs):
    """
    Attach a text label to each bar displaying its y value
    Note: label always outside. otherwise it's too hard to control as numbers can be very long
    """
    max_x_value = 1.0
    distance = max_x_value * 0.0025

    for bar in bars:
        text = text_format.format(bar.get_width())

        text_x = bar.get_width() + distance
        text_y = bar.get_y() + bar.get_height() / 2

        plt.text(text_x, text_y, text, va='center', **kwargs)

def label_bars(bars, text_format, **kwargs):
    """
    Attaches a label on every bar of a regular or horizontal bar chart
    """
    ys = [bar.get_y() for bar in bars]
    y_is_constant = all(y == ys[0] for y in ys)  # -> regular bar chart, since all all bars start on the same y level (0)

    if y_is_constant:
        _label_bar(bars, text_format, **kwargs)
    else:
        _label_barh(bars, text_format, **kwargs)

# %%
horizontal_bars = plt.barh(columns, gain, height= 0.5, align="center")
plt.xlim(0,1.0)
plt.ylabel('Features')
plt.xlabel('Importance')
value_format = "{:.4}"  # displaying values as percentage with one fractional digit
label_bars(horizontal_bars, value_format)

# %% [markdown]
# ## Hyperparameter-Optimized XGboost plots

# %%
plt.plot(df_base["log(f)"].values,df_base["phase"].values,'r',label = 'Experimental')
plt.plot(df_base["log(f)"].values,final_model.predict(df_base.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('Base')
plt.savefig('bode_xgb_ab.png',dpi=1200)
plt.show()

# %%
plt.plot(df_ht["log(f)"].values,df_ht["phase"].values,'r',label = 'Experimental')
plt.plot(df_ht["log(f)"].values,final_model.predict(df_ht.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('Base')
plt.savefig('bode_xgb_ht.png',dpi=1200)
plt.show()

# %%
plt.plot(df_sp["log(f)"].values,df_sp["phase"].values,'r',label = 'Experimental')
plt.plot(df_sp["log(f)"].values,final_model.predict(df_sp.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('Base')
plt.savefig('bode_xgb_sp.png',dpi=1200)
plt.show()

# %%
plt.plot(df_htsp["log(f)"].values,df_htsp["phase"].values,'r',label = 'Experimental')
plt.plot(df_htsp["log(f)"].values,final_model.predict(df_htsp.drop(['XY','log(absZ)','phase'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel("Log(f)    (in Hz)")
plt.ylabel("Phase angle   (in degrees)")
#plt.title('Base')
plt.savefig('bode_xgb_htsp.png',dpi=1200)
plt.show()
